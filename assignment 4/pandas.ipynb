# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
gross_product = pd.read_csv('gross.csv')
gross_product
# Out:
#     label  GDP_Per_Capita
# 0    2021    12335.859207
# 1    2020    10895.735233
# 2    2019    11330.453670
# 3    2018    11290.099975
# 4    2017    10746.856268
# ..    ...             ...
# 57   1964      561.424407
# 58   1963      523.401899
# 59   1962      495.967407
# 60   1961      471.686740
# 61   1960      456.826375
#
# [62 rows x 2 columns]

# %%
plt.plot(gross_product.label, gross_product.GDP_Per_Capita)
plt.title('Gross domestic product per capita in the World')
plt.xlabel('year')
plt.ylabel('GDP per capita')
plt.show()

# %%
plt.scatter(gross_product.label, gross_product.GDP_Per_Capita)
plt.title('Gross domestic product per capita in the World')
plt.xlabel('year')
plt.ylabel('GDP per capita')
plt.show()

# %%
urban_rural = pd.read_csv('urban_rural.csv')
urban_rural
# Out:
#     label  Urban_Population  Rural_Population
# 0    2019        4274233737      3.397468e+09
# 1    2018        4195079805      3.395019e+09
# 2    2017        4115696800      3.391541e+09
# 3    2016        4035616270      3.386853e+09
# 4    2015        3955764308      3.381377e+09
# 5    2014        3876973173      3.375406e+09
# 6    2013        3799327693      3.368458e+09
# 7    2012        3722958628      3.360961e+09
# 8    2011        3647814680      3.353217e+09
# 9    2010        3573952645      3.346106e+09
# 10   2009        3497462580      3.340313e+09
# 11   2008        3421413902      3.333720e+09
# 12   2007        3345860457      3.326574e+09
# 13   2006        3272638491      3.318341e+09
# 14   2005        3199838222      3.310170e+09
# 15   2004        3127696870      3.302117e+09
# 16   2003        3056824664      3.293322e+09
# 17   2002        2987277076      3.283743e+09
# 18   2001        2918728973      3.273212e+09
# ...

# %%
plt.plot(urban_rural.label, urban_rural.Urban_Population / 10 ** 9)
plt.plot(urban_rural.label, urban_rural.Rural_Population / 10 ** 9)
plt.title('Urban and rural population in the World')
plt.legend(['Urban', 'Rural'])
plt.xlabel('year')
plt.ylabel('population (billion)')
plt.show()

# %%
urban = pd.read_csv('urban.csv')
df = pd.DataFrame(urban)
urban
# Out:
#      country      value
# 0     Brazil  160925792
# 1  Argentina   23192892
# 2      Kenya   14831700
# 3     Israel    6799339
# 4     Uganda    6777800

# %%
x = list(df.iloc[:, 0])
y = list(df.iloc[:, 1])

plt.bar(x, y)
plt.title('Ranking by Population (Urban)')
plt.ylabel('population (100 million)')
plt.show()

# %%
rural = pd.read_csv('rural.csv')
rural
# Out:
#      country     value
# 0      Kenya  32732596
# 1     Uganda  30082900
# 2     Brazil  29830007
# 3  Argentina   4754554
# 4     Israel    612830

# %%
country = rural['country']
value = rural['value']
colors = ["#1f77b4", "#ff7f0e", "#2ca02c", "#d62728", "#8c564b"]
plt.title('Ranking by Population (Rural)')
plt.pie(value, labels=country, colors=colors,
autopct='%1.1f%%')
plt.show()
